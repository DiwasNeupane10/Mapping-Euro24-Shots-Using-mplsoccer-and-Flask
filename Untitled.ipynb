# %%
import pandas as pd
data=pd.read_csv('./euros_2024_shot_map.csv')
pd.set_option('display.max_columns',None)

# %%
data.head(2)
# Out:
#    50_50  bad_behaviour_card  ball_receipt_outcome  block_deflection  \
# 0    NaN                 NaN                   NaN               NaN
# 1    NaN                 NaN                   NaN               NaN
#
#    block_save_block  carry_end_location  clearance_aerial_won  \
# 0               NaN                 NaN                   NaN
# 1               NaN                 NaN                   NaN
#
#    clearance_body_part  clearance_head  clearance_left_foot  \
# 0                  NaN             NaN                  NaN
# 1                  NaN             NaN                  NaN
#
#    clearance_right_foot  counterpress  dribble_outcome  duel_outcome  \
# 0                   NaN           NaN              NaN           NaN
# 1                   NaN           NaN              NaN           NaN
#
#    duel_type  duration  foul_committed_advantage  foul_committed_card  \
# 0        NaN  0.865482                       NaN                  NaN
# ...

# %%
team=data['team'].sort_values().unique()

# %%
data['type']
# Out:
# 0       Shot
# 1       Shot
# 2       Shot
# 3       Shot
# 4       Shot
#         ...
# 1335    Shot
# 1336    Shot
# 1337    Shot
# 1338    Shot
# 1339    Shot
# Name: type, Length: 1340, dtype: object

# %%
data
# Out:
#       50_50  bad_behaviour_card  ball_receipt_outcome  block_deflection  \
# 0       NaN                 NaN                   NaN               NaN
# 1       NaN                 NaN                   NaN               NaN
# 2       NaN                 NaN                   NaN               NaN
# 3       NaN                 NaN                   NaN               NaN
# 4       NaN                 NaN                   NaN               NaN
# ...     ...                 ...                   ...               ...
# 1335    NaN                 NaN                   NaN               NaN
# 1336    NaN                 NaN                   NaN               NaN
# 1337    NaN                 NaN                   NaN               NaN
# 1338    NaN                 NaN                   NaN               NaN
# 1339    NaN                 NaN                   NaN               NaN
#
#       block_save_block  carry_end_location  clearance_aerial_won  \
# ...

# %%
 data=data[data['type']=='Shot'].reset_index(drop=True)

# %%
data
# Out:
#       50_50  bad_behaviour_card  ball_receipt_outcome  block_deflection  \
# 0       NaN                 NaN                   NaN               NaN
# 1       NaN                 NaN                   NaN               NaN
# 2       NaN                 NaN                   NaN               NaN
# 3       NaN                 NaN                   NaN               NaN
# 4       NaN                 NaN                   NaN               NaN
# ...     ...                 ...                   ...               ...
# 1335    NaN                 NaN                   NaN               NaN
# 1336    NaN                 NaN                   NaN               NaN
# 1337    NaN                 NaN                   NaN               NaN
# 1338    NaN                 NaN                   NaN               NaN
# 1339    NaN                 NaN                   NaN               NaN
#
#       block_save_block  carry_end_location  clearance_aerial_won  \
# ...

# %%
team
# Out:
# array(['Albania', 'Austria', 'Belgium', 'Croatia', 'Czech Republic',
#        'Denmark', 'England', 'France', 'Georgia', 'Germany', 'Hungary',
#        'Italy', 'Netherlands', 'Poland', 'Portugal', 'Romania',
#        'Scotland', 'Serbia', 'Slovakia', 'Slovenia', 'Spain',
#        'Switzerland', 'Turkey', 'Ukraine'], dtype=object)

# %%
def select_players(teams):
        return data[data['team']==teams]['player'].sort_values().unique()

# %%
select_players('Albania')
# Out:
# array(['Arbër Hoxha', 'Armando Broja', 'Berat Djimsiti', 'Elseid Hysaj',
#        'Jasir Asani', 'Klaus Gjasula', 'Kristjan Asllani', 'Mario Mitaj',
#        'Medon Berisha', 'Mirlind Daku', 'Nedim Bajrami', 'Qazim Laçi',
#        'Rey Manaj', 'Taulant Sulejmanov'], dtype=object)

# %%
test=pd.read_csv('./euros_2024_shot_map.csv')

# %%
test=test[test['type']=='Shot'].reset_index(drop=True)

# %%
test
# Out:
#       50_50  bad_behaviour_card  ball_receipt_outcome  block_deflection  \
# 0       NaN                 NaN                   NaN               NaN
# 1       NaN                 NaN                   NaN               NaN
# 2       NaN                 NaN                   NaN               NaN
# 3       NaN                 NaN                   NaN               NaN
# 4       NaN                 NaN                   NaN               NaN
# ...     ...                 ...                   ...               ...
# 1335    NaN                 NaN                   NaN               NaN
# 1336    NaN                 NaN                   NaN               NaN
# 1337    NaN                 NaN                   NaN               NaN
# 1338    NaN                 NaN                   NaN               NaN
# 1339    NaN                 NaN                   NaN               NaN
#
#       block_save_block  carry_end_location  clearance_aerial_won  \
# ...

# %%
test2=pd.read_csv('./euros_2024_shot_map.csv')

# %%
test2=data['team'].sort_values().unique()

# %%
test2
# Out:
# array(['Albania', 'Austria', 'Belgium', 'Croatia', 'Czech Republic',
#        'Denmark', 'England', 'France', 'Georgia', 'Germany', 'Hungary',
#        'Italy', 'Netherlands', 'Poland', 'Portugal', 'Romania',
#        'Scotland', 'Serbia', 'Slovakia', 'Slovenia', 'Spain',
#        'Switzerland', 'Turkey', 'Ukraine'], dtype=object)

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ---------------
# absl-py                   2.1.0
# anyio                     4.3.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asgiref                   3.7.2
# asttokens                 2.4.1
# astunparse                1.6.3
# async-lru                 2.0.4
# attrs                     23.2.0
# Babel                     2.14.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# blinker                   1.8.2
# certifi                   2024.2.2
# cffi                      1.16.0
# channels                  4.0.0
# charset-normalizer        3.3.2
# click                     8.1.7
# colorama                  0.4.6
# comm                      0.2.1
# contourpy                 1.2.0
# cycler                    0.12.1
# debugpy                   1.8.1
# decorator                 5.1.1
# defusedxml                0.7.1
# ...

# %%
from mplsoccer import VerticalPitch

# %%
help(VerticalPitch)
# Out:
# Help on class VerticalPitch in module mplsoccer.pitch:
#
# class VerticalPitch(mplsoccer._pitch_plot.BasePitchPlot)
#  |  VerticalPitch(pitch_type='statsbomb', half=False, pitch_color=None, line_color=None, line_alpha=1, linewidth=2, linestyle=None, line_zorder=0.9, spot_scale=0.002, spot_type='circle', stripe=False, stripe_color='#c2d59d', stripe_zorder=0.6, pad_left=None, pad_right=None, pad_bottom=None, pad_top=None, positional=False, positional_zorder=0.8, positional_linewidth=None, positional_linestyle=None, positional_color='#eadddd', positional_alpha=1, shade_middle=False, shade_color='#f2f2f2', shade_alpha=1, shade_zorder=0.7, pitch_length=None, pitch_width=None, goal_type='line', goal_alpha=1, goal_linestyle=None, axis=False, label=False, tick=False, corner_arcs=False)
#  |
#  |  Method resolution order:
#  |      VerticalPitch
#  |      mplsoccer._pitch_plot.BasePitchPlot
#  |      mplsoccer._pitch_base.BasePitch
#  |      abc.ABC
#  |      builtins.object
#  |
# ...
